# %%
import requests
from bs4 import BeautifulSoup

# %%
resp = requests.get("https://www.proquest.com/search/2828552?accountid=14965")

# %%
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.text)
print(soup.prettify())
# Out:
# <html data-locale="en" ns0:windowtitle="ProQuest" xmlns:ns0="http://tapestry.apache.org/schema/tapestry_5_1_0.xsd">
#  <head>
#   <link href="/assets/meta/z16e9c260/tapestry5/font_awesome/css/font-awesome.css" rel="stylesheet" type="text/css"/>
#   <link href="/assets/meta/1/tapestry/css/bootstrap.css" rel="stylesheet" type="text/css"/>
#   <link href="/assets/meta/z3b36fd2b/tapestry5/tapestry.css" rel="stylesheet" type="text/css"/>
#   <link href="/assets/meta/z46ba6ee5/tapestry5/exception-frame.css" rel="stylesheet" type="text/css"/>
#   <link href="/assets/meta/z9cac79b1/tapestry5/tapestry-console.css" rel="stylesheet" type="text/css"/>
#   <link href="/assets/meta/zd721e6a2/tapestry5/tree.css" rel="stylesheet" type="text/css"/>
#  </head>
#  <body data-page-initialized="false">
#   <script type="text/javascript">
# ...
